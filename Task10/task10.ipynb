# %% [markdown]
# # AI-Lab: 10
# ### Rollnumber: BSDS 3A
# ### Name: Ayesha sikander

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Data Gathering and Data Loading

# %%
df = pd.read_csv("Laptop_price.csv")
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %% [markdown]
# ### Data Exploration

# %%
df.head(2)
# Out:
#   Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0  Asus         3.830296        16               512    11.185147  2.641094
# 1  Acer         2.912833         4              1000    11.311372  3.260012
#
#           Price
# 0  17395.093065
# 1  31607.605919

# %%
df.tail(2)
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight        Price
# 998  3.857613  9407.473459
# 999  3.440883  8807.696702

# %%
df.columns
# Out:
# Index(['Brand', 'Processor_Speed', 'RAM_Size', 'Storage_Capacity',
#        'Screen_Size', 'Weight', 'Price'],
#       dtype='object')

# %%
df.count()
# Out:
# Brand               1000
# Processor_Speed     1000
# RAM_Size            1000
# Storage_Capacity    1000
# Screen_Size         1000
# Weight              1000
# Price               1000
# dtype: int64

# %%
df.describe()
# Out:
#        Processor_Speed     RAM_Size  Storage_Capacity  Screen_Size  \
# count      1000.000000  1000.000000       1000.000000  1000.000000
# mean          2.750611    15.500000        584.576000    14.056790
# std           0.731796    10.988665        313.438517     1.705882
# min           1.511580     4.000000        256.000000    11.012111
# 25%           2.089246     8.000000        256.000000    12.635523
# 50%           2.760885    16.000000        512.000000    14.099643
# 75%           3.362610    32.000000       1000.000000    15.528590
# max           3.998534    32.000000       1000.000000    16.985737
#
#             Weight         Price
# count  1000.000000   1000.000000
# mean      3.466919  19604.187963
# std       0.866541   9406.064880
# min       2.000560   8570.012950
# 25%       2.717211  10114.012948
# 50%       3.464630  17287.241878
# 75%       4.212583  31566.214754
# max       4.990728  33503.935037

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             1000 non-null   object
#  1   Processor_Speed   1000 non-null   float64
#  2   RAM_Size          1000 non-null   int64
#  3   Storage_Capacity  1000 non-null   int64
#  4   Screen_Size       1000 non-null   float64
#  5   Weight            1000 non-null   float64
#  6   Price             1000 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 54.8+ KB

# %%
df.shape
print(f"Number of Rows: {df.shape[0]} and Number of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 1000 and Number of Columns: 7

# %%
df['Weight'].unique()
# Out:
# array([2.64109442, 3.26001222, 2.02906065, 4.57386527, 4.19347203,
#        4.84026811, 4.34484644, 2.94111954, 2.74362008, 4.09314892,
#        3.09233833, 3.69864505, 2.01877241, 2.18565711, 3.60610382,
#        3.69821494, 4.25435883, 2.39589596, 3.53954925, 2.58334293,
#        2.27958836, 3.23148738, 2.49000994, 2.66534593, 2.95266374,
#        2.7781652 , 2.26277389, 2.26974873, 2.57974825, 2.15167756,
#        3.87937106, 2.86198015, 2.8392379 , 2.99599488, 3.98838882,
#        4.61190164, 4.2772608 , 4.18258769, 3.45317356, 4.08141667,
#        3.6582871 , 2.64875158, 2.6257651 , 2.88917602, 4.73240801,
#        3.64224452, 4.20171613, 3.03967628, 3.22314731, 2.37669674,
#        2.51388487, 4.48206966, 3.7545159 , 3.0125974 , 4.40855363,
#        2.73955972, 4.9280981 , 3.03445282, 3.01193286, 2.93573572,
#        2.36633455, 2.33341144, 3.9443151 , 4.62535413, 4.37156153,
#        2.42332278, 3.63674637, 2.31677464, 2.13588393, 3.96915758,
# ...

# %%
df.nunique()
# Out:
# Brand                  5
# Processor_Speed     1000
# RAM_Size               4
# Storage_Capacity       3
# Screen_Size         1000
# Weight              1000
# Price               1000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# ### Data Pre-Processing

# %% [markdown]
# ### Manage Null Values

# %%
df = df.drop('Price',axis=1)

# %%
df = df.drop('Brand',axis=1)

# %%
def fillnaObjectMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns = ['Screen_Size', 'RAM_Size']
fillnaObjectMode(columns)

# %%
def fillnaIntMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns = ['Screen_Size','RAM_Size']
fillnaIntMode(columns)

# %%
def fillnaFloatMean(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mean())

columns = ['Screen_Size','RAM_Size']
fillnaFloatMean(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Processor_Speed   1000 non-null   float64
#  1   RAM_Size          1000 non-null   int64
#  2   Storage_Capacity  1000 non-null   int64
#  3   Screen_Size       1000 non-null   float64
#  4   Weight            1000 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 39.2 KB

# %% [markdown]
# Manage Data Types

# %%
df['Weight'] = df['Weight'].astype('int64')

# %%
def changeFloatToInt(cols):
    for i in cols:
        df[i] = df[i].astype('int64')

columns = ['Screen_Size', 'RAM_Size']
changeFloatToInt(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Processor_Speed   1000 non-null   float64
#  1   RAM_Size          1000 non-null   int64
#  2   Storage_Capacity  1000 non-null   int64
#  3   Screen_Size       1000 non-null   int64
#  4   Weight            1000 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 39.2 KB

# %%
def convertObjToInt(cols):
    for i in cols:
        data = pd.DataFrame({i:df[i].unique()})
        data_LE = LabelEncoder()
        data_LE.fit(np.ravel(data))    
        df[i] = data_LE.transform(df[i])
        
columns = ['Screen_Size', 'RAM_Size']
convertObjToInt(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Processor_Speed   1000 non-null   float64
#  1   RAM_Size          1000 non-null   int64
#  2   Storage_Capacity  1000 non-null   int64
#  3   Screen_Size       1000 non-null   int64
#  4   Weight            1000 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 39.2 KB

# %%
df.head(3)
# Out:
#    Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  Weight
# 0         3.830296         2               512            0       2
# 1         2.912833         0              1000            0       3
# 2         3.241627         0               256            0       2

# %%
df.to_csv('Laptop_price.csv',index=False,header=True)

# %%
df = pd.read_csv('Laptop_price.csv')
